# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)

plt.plot(x, np.sin(x)    , '-r')
plt.plot(x, np.sin(x) + 1, '--g')
plt.plot(x, np.sin(x) - 1, '-.b')
plt.plot(x, np.cos(x)    , ':c')
plt.plot(x, np.cos(x) + 1, '--m')
plt.plot(x, np.cos(x) - 1, '-y')
plt.plot(x, x * 0.1      , ':k')

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, 
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8)
plt.ylim(0, 1.0)
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.title("TITLE")
# Out:
# Text(0.5, 1.0, 'TITLE')

# %%
x = np.linspace(0, 10, 1000)

fig, ax = plt.subplots(2, 3)

ax[0,0].plot(x)
ax[0,1].plot(-x)
ax[0,2].plot(np.log(x+1))
ax[1,0].plot(np.exp(x)-1)
ax[1,1].plot(np.sin(x))
ax[1,2].plot(np.cos(x))

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]] #共分散
x, y = np.random.multivariate_normal(mean, cov, 3000).T

fig = plt.figure(figsize=(6,6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
# matplotlib
plt.scatter(x, y) #散布図
plt.errorbar(x, y, yerr=?)　#誤差の可視化  plt.fill_between(x, ymin, ymax)
plt.contour(x, y, f(x,y)) #３次元関数   contourfで塗りつぶし、colorbar()で軸追加、plt.imshow()
plt.hist(data) #ヒストグラム plt.hist2d(x,y) , plt.hexbin(x,y) で２次元化

# %%
# matplotlib 3D
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot3D(xline, yline, zline)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens')
ax.contour3D(x, y, z, 50, cmap='binary')
ax.plot_wireframe(x, y, z, cmap='black')
ax.plot_surface(x, y, z, rstride=1, cstride=1,
                cmap='binary', edgecolor='none') #trisurfもあり

# %%
# 地理データの処理
conda install basemap
from mpl_toolkits.basemap import Basemap
#pillowパッケージがいる

# %%
#Seaborn
sns.kdeplot() #１次元と２次元でグラフの表示の仕方が変わる
sns.distplot()　#カーネルとヒストグラムの融合
sns.jointplot() #結合分布
sns.pairplot() #変数の２乗個グラフができるので容量に注意
sns.FacetGrid()
sns.factorplot()
#下の奴は調べて使う
